# %%
#Importing pyplot

from matplotlib import pyplot as plt
# %matplotlib inline
#Plotting to our canvas
plt.plot([1,2,3],[4,5,1])

#Showing what we plotted
plt.show()

# %% [markdown]
# ### With Labelling the Axis

# %%
from matplotlib import pyplot as plt

x = [5,8,10]
y = [12,16,6]

plt.plot(x,y)

plt.title('Epic Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %% [markdown]
# ### Use Frame Style

# %%
from matplotlib import pyplot as plt
from matplotlib import style 

style.use('ggplot') #use style ggplot

x = [5,8,10]
y = [12,16,6]

x2 = [6,9,11]
y2 = [6,15,7]

# can plot specifically, after just showing the defaults:
plt.plot(x,y,linewidth=5)
plt.plot(x2,y2,linewidth=5)

plt.title('Epic Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %% [markdown]
# ## Bar Chart

# %%
from matplotlib import pyplot as plt
from matplotlib import style

style.use('ggplot')

x = [5,8,10]
y = [12,16,6]

x2 = [6,9,11]
y2 = [6,15,7]


plt.bar(x, y, align='center')

plt.bar(x2, y2, color='g', align='center')


plt.title('Epic Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
from matplotlib import pyplot as plt
from matplotlib import style

style.use('ggplot')

x = [5,8,10]
y = [12,16,6]

x2 = [6,9,11]
y2 = [6,15,7]

plt.scatter(x, y)#, align='center')

plt.scatter(x2, y2, color='g')#, align='center')


plt.title('Epic Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %% [markdown]
# ### Plotting DataFrame

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd

style.use('ggplot')
df = pd.read_csv('C:/Users/Putra/Downloads/GOOG(1).csv')
df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2018-10-18  1121.839966  1121.839966  1077.089966  1087.969971
# 1  2018-10-19  1093.369995  1110.359985  1087.750000  1096.459961
# 2  2018-10-22  1103.060059  1112.229980  1091.000000  1101.160034
# 3  2018-10-23  1080.890015  1107.890015  1070.000000  1103.689941
# 4  2018-10-24  1104.250000  1106.119995  1048.739990  1050.709961
#
#      Adj Close   Volume
# 0  1087.969971  2094500
# 1  1096.459961  1267600
# 2  1101.160034  1514200
# 3  1103.689941  1848700
# 4  1050.709961  1982400

# %%
data = df[['Open','Close']]

# %%
data.plot(x = 'Open', y = 'Close', style = 'o') #plotting data dengan x = kolom 'Open', dan y = kolom 'Close'

# %% [markdown]
# ## Exercise

# %% [markdown]
# 1. Download Data Sutdents Performance in Kaggle <br>
#     a). read data tersebut dengan menggunakan read_csv pandas
#     a). Print 10 baris pertama data tersebut <br>
#     b). Buat data frame baru yang isinya  kolom  'race/etnicity' dan 'lunch' di data students performance <br>
#     c). Cari Mean masing2 kolom 'math score', 'reading score', 'writing score' <br>
#     d). Scatter Plot dengan x adalah kolom 'reading score' dan y adalah kolom 'writing score' <br>
# 2. Download Data 'property data' dari github <br>
#     a). read data tersebut dengan read_csv <br>
#     b). fill missing value dengan metode 'pad' <br>
#     c). fill missing value dengan metode 'bfill' <br>
